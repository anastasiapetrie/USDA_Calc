# %%
import pandas as pd

# %%
tomato = pd.read_csv('/Users/anastasia.petrie/Desktop/USDA_Calc/Data/tomato_report.csv')

# %%
print tomato
# Out:
#     Commodity Name                           City Name  Type  \
# 0         TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 1         TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 2         TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 3         TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 4         TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 5         TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 6         TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 7         TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 8         TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 9         TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 10        TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 11        TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 12        TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# 13        TOMATOES         CENTRAL DISTRICT CALIFORNIA   NaN
# ...

# %%
t = pd.DataFrame(tomato)

# %%
t.tail(5)
# Out:
#     Commodity Name                           City Name  Type          Package  \
# 793       TOMATOES  MEXICO CROSSINGS THROUGH OTAY MESA   NaN  cartons 2 layer
# 794       TOMATOES  MEXICO CROSSINGS THROUGH OTAY MESA   NaN  cartons 2 layer
# 795       TOMATOES  MEXICO CROSSINGS THROUGH OTAY MESA   NaN  cartons 2 layer
# 796       TOMATOES  MEXICO CROSSINGS THROUGH OTAY MESA   NaN  cartons 2 layer
# 797       TOMATOES  MEXICO CROSSINGS THROUGH OTAY MESA   NaN  cartons 2 layer
#
#         Variety  Sub Variety  Grade      Date  Low Price  High Price  \
# 793  VINE RIPES          NaN    NaN  11/27/15      10.95       12.95
# 794  VINE RIPES          NaN    NaN  11/30/15        NaN         NaN
# 795  VINE RIPES          NaN    NaN  11/30/15        NaN         NaN
# 796  VINE RIPES          NaN    NaN  11/30/15        NaN         NaN
# 797  VINE RIPES          NaN    NaN  11/30/15        NaN         NaN
#
#         ...       Purchase Lot Size  Section or Sale  Import/Export  \
# ...

# %%
list(t.columns.values)
# Out:
# ['Commodity Name',
#  'City Name',
#  'Type',
#  'Package',
#  'Variety',
#  'Sub Variety',
#  'Grade',
#  'Date',
#  'Low Price',
#  'High Price',
#  'Mostly Low',
#  'Mostly High',
#  'Season',
#  'Item Size',
#  'Color',
#  'Environment',
#  'Unit of Sale',
#  'Quality',
#  'Condition',
#  'Appearance',
#  'Storage',
#  'Shelled/Unshelled',
#  'Purchase Lot Size',
#  'Section or Sale',
#  'Import/Export',
#  'Supply Tone',
#  'Demand Tone',
#  'Basis of Sale',
#  'Market Tone',
#  'Price Comment',
#  'Comments',
#  'Rpt City']

# %%
t.shape
# Out:
# (798, 32)

# %%
t['Import/Export'].unique()
# Out:
# array([ nan])

# %%
t['City Name'].unique()
# Out:
# array(['CENTRAL DISTRICT CALIFORNIA', 'MEXICO CROSSINGS THROUGH OTAY MESA'], dtype=object)

# %%
t['Item Size'].unique()
# Out:
# array([nan, 'xlge', 'lge', 'med', 'jbo', '4x4s', '4x5s', '5x5s', '5x6s'], dtype=object)

# %%
t['Supply Tone'].unique()
# Out:
# array(['LIGHT.', nan, 'EXTRA LARGE FAIRLY HEAVY.',
#        'JUMBO AND EXTRA LARGE FAIRLY HEAVY.', 'FAIRLY LIGHT.',
#        'EXTRA LARGE FAIRLY LIGHT.', 'VERY LIGHT.', 'FAIRLY HEAVY.',
#        '4X4-4X5S HEAVY.', '4X4 FAIRLY HEAVY.', '4X4-4X5S FAIRLY HEAVY.',
#        '5X6S LIGHT.', '5X5-5X6S VERY LIGHT, OTHERS LIGHT.',
#        '4X4-4X5S LIGHT.', '4X5S LIGHT.'], dtype=object)

# %%
old_names = [
 'Commodity Name',
 'City Name',
 'Type',
 'Package',
 'Variety',
 'Sub Variety',
 'Grade',
 'Date',
 'Low Price',
 'High Price',
 'Mostly Low',
 'Mostly High',
 'Season',
 'Item Size',
 'Color',
 'Environment',
 'Unit of Sale',
 'Quality',
 'Condition',
 'Appearance',
 'Storage',
 'Shelled/Unshelled',
 'Purchase Lot Size',
 'Section or Sale',
 'Import/Export',
 'Supply Tone',
 'Demand Tone',
 'Basis of Sale',
 'Market Tone',
 'Price Comment',
 'Comments',
 'Rpt City'] 
new_names = [
 'commodity',
 'city',
 'type',
 'package',
 'variety',
 'sub_variety',
 'grade',
 'date',
 'low_price',
 'high_price',
 'mostly_low',
 'mostly_high',
 'season',
 'size',
 'color',
 'environment',
 'unit_of_sale',
 'quality',
 'condition',
 'appearance',
 'storage',
 'shelled',
 'purchase-lot_size',
 'section',
 'import',
 'supply_tone',
 'demand_tone',
 'basis_of_sale',
 'market_tone',
 'Price Comment',
 'comments',
 'rpt_city']
t.rename(columns=dict(zip(old_names, new_names)), inplace=True)

# %%
list(t.columns.values)
# Out:
# ['commodity',
#  'city',
#  'type',
#  'package',
#  'variety',
#  'sub_variety',
#  'grade',
#  'date',
#  'low_price',
#  'high_price',
#  'mostly_low',
#  'mostly_high',
#  'season',
#  'size',
#  'color',
#  'environment',
#  'unit_of_sale',
#  'quality',
#  'condition',
#  'appearance',
#  'storage',
#  'shelled',
#  'purchase-lot_size',
#  'section',
#  'import',
#  'supply_tone',
#  'demand_tone',
#  'basis_of_sale',
#  'market_tone',
#  'Price Comment',
#  'comments',
#  'rpt_city']

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics
import statsmodels.formula.api as smf

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.pairplot(t, x_vars=['market_tone', 'package', 'demand_tone'], y_vars='mostly_high', size=6, aspect=0.7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b40a87879d48> in <module>()
# ----> 1 sns.pairplot(t, x_vars=['market_tone', 'package', 'demand_tone'], y_vars='mostly_high', size=6, aspect=0.7)
#
# /Users/anastasia.petrie/anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    1615     if kind == "scatter":
#    1616         plot_kws.setdefault("edgecolor", "white")
# -> 1617         plotter(plt.scatter, **plot_kws)
#    1618     elif kind == "reg":
#    1619         plotter(regplot, **plot_kws)
#
# /Users/anastasia.petrie/anaconda/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map(self, func, **kwargs)
#    1271                     color = self.palette[k] if kw_color is None else kw_color
# ...
